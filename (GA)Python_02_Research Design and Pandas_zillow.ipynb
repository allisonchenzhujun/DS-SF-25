# %%
import os
import pandas as pd
pd.set_option('display.max_rows', 6)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

# %%
url = "https://raw.githubusercontent.com/allisonchenzhujun/DS-SF-25/master/classes/02/datasets/zillow-02-starter.csv"
df = pd.read_csv(url)


# Use Pandas to clean up dataset
# df2 = pd.read_csv(os.path.join('..', 'datasets', 'zillow-02-starter.csv'), index_col = 'ID')
# b'../datasets/zillow-02-starter.csv' does not exist (need to add local file if want to use this command)

# %%
df.ix[:,0]
# Out:
# /Users/Allison/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.
# 0        15063471
# 1        15063505
# 2        15063609
#           ...
# 997    2128308939
# 998    2131957929
# 999    2136213970
# Name: ID, Length: 1000, dtype: int64

# %%
df['ID']
# Out:
# 0        15063471
# 1        15063505
# 2        15063609
#           ...
# 997    2128308939
# 998    2131957929
# 999    2136213970
# Name: ID, Length: 1000, dtype: int64

# %%
# Check the type of the db, dataframe stores tabular data. 
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1000, 15)

# %%
#display column name. 
df.columns
# Out:
# Index(['ID', 'Address', 'Latitude', 'Longitude', 'DateOfSale', 'SalePrice',
#        'SalePriceUnit', 'IsAStudio', 'BedCount', 'BathCount', 'Size',
#        'SizeUnit', 'LotSize', 'LotSizeUnit', 'BuiltInYear'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  ID      Latitude     Longitude      SalePrice    BedCount  \
# count  1.000000e+03  1.000000e+03  1.000000e+03    1000.000000  836.000000
# mean   1.591666e+08  3.775959e+07 -1.224348e+08  298264.042160    2.572967
# std    4.928856e+08  2.531078e+04  3.157521e+04  381637.332787    1.250891
# ...             ...           ...           ...            ...         ...
# 50%    1.516415e+07  3.776023e+07 -1.224317e+08       2.500000    2.000000
# 75%    6.739436e+07  3.777999e+07 -1.224098e+08  718500.000000    3.000000
# max    2.136214e+09  3.780543e+07 -1.223712e+08  999000.000000    9.000000
#
#         BathCount          Size       LotSize  BuiltInYear
# count  942.000000    967.000000    556.000000   975.000000
# mean     1.977548   1641.300931   2809.112770  1947.533333
# std      1.130334   1027.016175   1097.087521    38.021563
# ...           ...           ...           ...          ...
# 50%      2.000000   1350.000000   2613.000000  1939.000000
# ...

# %%
type(df)
df.shape
# Out:
# (1000, 15)

# %%
#transpose the data 
df.T
# Out:
#                                                    0    \
# ID                                            15063471
# Address      55 Vandewater St APT 9, San Francisco, CA
# Latitude                                      37805103
# ...                                                ...
# LotSize                                            NaN
# LotSizeUnit                                        NaN
# BuiltInYear                                       1980
#
#                                              1    \
# ID                                      15063505
# Address      740 Francisco St, San Francisco, CA
# Latitude                                37804420
# ...                                          ...
# LotSize                                     2435
# LotSizeUnit                                 sqft
# BuiltInYear                                 1948
#
#                                              2    \
# ID                                      15063609
# ...

# %%
#redefine index
df = df.set_index('ID')
# sort by column 
# df.sort_values('ID')

# %%
df.head()
# Out:
#                                              Address  Latitude  Longitude  \
# ID
# 15063471   55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 15063505         740 Francisco St, San Francisco, CA  37804420 -122417389
# 15063609         819 Francisco St, San Francisco, CA  37803728 -122419055
# 15064044    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 15064257  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
#
#          DateOfSale  SalePrice     ...         Size SizeUnit  LotSize  \
# ID                                 ...
# 15063471    12/4/15  710000.00     ...        550.0     sqft      NaN
# 15063505   11/30/15       2.15     ...       1430.0     sqft   2435.0
# 15063609   11/12/15       5.60     ...       2040.0     sqft   3920.0
# 15064044   12/11/15       1.50     ...       1060.0     sqft      NaN
# 15064257    1/15/16  970000.00     ...       1299.0     sqft      NaN
#
#           LotSizeUnit  BuiltInYear
# ID
# ...

# %%
#Getting and subsetting the data
# selecting single column 
df['Address']
#selecing singel row 
df[0:3]
# Out:
#                                             Address  Latitude  Longitude  \
# ID
# 15063471  55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 15063505        740 Francisco St, San Francisco, CA  37804420 -122417389
# 15063609        819 Francisco St, San Francisco, CA  37803728 -122419055
#
#          DateOfSale  SalePrice     ...         Size SizeUnit  LotSize  \
# ID                                 ...
# 15063471    12/4/15  710000.00     ...        550.0     sqft      NaN
# 15063505   11/30/15       2.15     ...       1430.0     sqft   2435.0
# 15063609   11/12/15       5.60     ...       2040.0     sqft   3920.0
#
#           LotSizeUnit  BuiltInYear
# ID
# 15063471          NaN       1980.0
# 15063505         sqft       1948.0
# 15063609         sqft       1976.0
#
# [3 rows x 14 columns]

# %%
#selecting by label 
df.columns
df.loc[:,['Address','SalePriceUnit']]
# Out:
#                                               Address SalePriceUnit
# ID
# 15063471    55 Vandewater St APT 9, San Francisco, CA             $
# 15063505          740 Francisco St, San Francisco, CA            $M
# 15063609          819 Francisco St, San Francisco, CA            $M
# ...                                               ...           ...
# 2128308939       33 Santa Cruz Ave, San Francisco, CA             $
# 2131957929          1821 Grant Ave, San Francisco, CA             $
# 2136213970           1200 Gough St, San Francisco, CA             $
#
# [1000 rows x 2 columns]

# %%
#selecting by location 
df.iloc[3:5,0:2]
df.iloc[3:5,:]  
df.iat[1,1] #position value, #equiv to df.iloc[1,1]
#Get number of column by label 
df.columns.get_loc('BedCount')
# Out:
# 7

# %%
#Subsset case when 
df[df.Size > 2000]
#ues isin as filtering 
df[df['BuiltInYear'].isin(['1913.0','1943.0'])]
# Out:
#                                              Address  Latitude  Longitude  \
# ID
# 15064536      2300 Leavenworth St, San Francisco, CA  37802408 -122417537
# 15066839     1163-1165 Vallejo St, San Francisco, CA  37797445 -122416366
# 15069276      795 Sutter St # 303, San Francisco, CA  37788404 -122413260
# ...                                              ...       ...        ...
# 15195675          115 Sickles Ave, San Francisco, CA  37709197 -122453677
# 79843553    1015 Ashbury St APT 2, San Francisco, CA  37764320 -122446342
# 2106229715          2595 38th Ave, San Francisco, CA  37738600 -122496000
#
#            DateOfSale  SalePrice     ...         Size SizeUnit  LotSize  \
# ID                                   ...
# 15064536      12/4/15       2.83     ...       2115.0     sqft   1271.0
# 15066839      12/1/15  300000.00     ...       2344.0     sqft   1376.0
# 15069276     11/15/15       1.20     ...       1753.0     sqft      NaN
# ...

# %%
# subset with multiple conditions. 
df[(df.LotSize > 100) & (df.BuiltInYear >1900)]
# Out:
#                                            Address  Latitude  Longitude  \
# ID
# 15063505       740 Francisco St, San Francisco, CA  37804420 -122417389
# 15063609       819 Francisco St, San Francisco, CA  37803728 -122419055
# 15064536    2300 Leavenworth St, San Francisco, CA  37802408 -122417537
# ...                                            ...       ...        ...
# 2101169168      688 Douglass St, San Francisco, CA  37752803 -122438919
# 2106229715        2595 38th Ave, San Francisco, CA  37738600 -122496000
# 2128308939    33 Santa Cruz Ave, San Francisco, CA  37709136 -122465332
#
#            DateOfSale  SalePrice     ...         Size SizeUnit  LotSize  \
# ID                                   ...
# 15063505     11/30/15       2.15     ...       1430.0     sqft   2435.0
# 15063609     11/12/15       5.60     ...       2040.0     sqft   3920.0
# 15064536      12/4/15       2.83     ...       2115.0     sqft   1271.0
# ...

# %%
#Subset on column simultaneously with multiple conditions. 
df[(df.LotSize > 100) & (df.BuiltInYear >1900)]['Address']
# Out:
# ID
# 15063505         740 Francisco St, San Francisco, CA
# 15063609         819 Francisco St, San Francisco, CA
# 15064536      2300 Leavenworth St, San Francisco, CA
#                                ...
# 2101169168        688 Douglass St, San Francisco, CA
# 2106229715          2595 38th Ave, San Francisco, CA
# 2128308939      33 Santa Cruz Ave, San Francisco, CA
# Name: Address, Length: 494, dtype: object

# %%
df.head(3)
# Out:
#                                             Address  Latitude  Longitude  \
# ID
# 15063471  55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 15063505        740 Francisco St, San Francisco, CA  37804420 -122417389
# 15063609        819 Francisco St, San Francisco, CA  37803728 -122419055
#
#          DateOfSale  SalePrice     ...         Size SizeUnit  LotSize  \
# ID                                 ...
# 15063471    12/4/15  710000.00     ...        550.0     sqft      NaN
# 15063505   11/30/15       2.15     ...       1430.0     sqft   2435.0
# 15063609   11/12/15       5.60     ...       2040.0     sqft   3920.0
#
#           LotSizeUnit  BuiltInYear
# ID
# 15063471          NaN       1980.0
# 15063505         sqft       1948.0
# 15063609         sqft       1976.0
#
# [3 rows x 14 columns]

# %%
#Scale all $value to $. 
df.SalePriceUnit.unique()
# Out:
# array(['$', '$M'], dtype=object)

# %%
#Scale all price into the same unit. 
df_1 = df[df.SalePriceUnit == '$']
df_2 = df[df.SalePriceUnit == '$M']
#here the axis =1 apply a method across each row. = 0, apply to each column. 
df_1 = df_1.drop('SalePriceUnit',axis = 1)
df_2 = df_2.drop('SalePriceUnit',axis = 1)

#Replace the content in a column
df_2.SalePrice = df_2.SalePrice * (10 **6)
df = pd.concat([df_1,df_2])

# %%
df.sort_index()
# Out:
#                                               Address  Latitude  Longitude  \
# ID
# 15063471    55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 15063505          740 Francisco St, San Francisco, CA  37804420 -122417389
# 15063609          819 Francisco St, San Francisco, CA  37803728 -122419055
# ...                                               ...       ...        ...
# 2128308939       33 Santa Cruz Ave, San Francisco, CA  37709136 -122465332
# 2131957929          1821 Grant Ave, San Francisco, CA  37803760 -122408531
# 2136213970           1200 Gough St, San Francisco, CA  37784770 -122424100
#
#            DateOfSale  SalePrice     ...        Size  SizeUnit  LotSize  \
# ID                                   ...
# 15063471      12/4/15   710000.0     ...       550.0      sqft      NaN
# 15063505     11/30/15  2150000.0     ...      1430.0      sqft   2435.0
# 15063609     11/12/15  5600000.0     ...      2040.0      sqft   3920.0
# ...

# %%
df.drop(['Latitude','Longitude'],axis =1, inplace = True)

# %%
df
# Out:
#                                                Address DateOfSale  SalePrice  \
# ID
# 15063471     55 Vandewater St APT 9, San Francisco, CA    12/4/15   710000.0
# 15064257    111 Chestnut St APT 403, San Francisco, CA    1/15/16   970000.0
# 15064295    111 Chestnut St APT 702, San Francisco, CA   12/17/15   940000.0
# ...                                                ...        ...        ...
# 2108546010    1738 Lombard St APT 4, San Francisco, CA    1/14/16  1400000.0
# 2121221385            925 Larkin St, San Francisco, CA   11/30/15  1430000.0
# 2122992200           129 Octavia St, San Francisco, CA   11/20/15  2750000.0
#
#            IsAStudio  BedCount     ...        Size  SizeUnit LotSize  \
# ID                                 ...
# 15063471       False       1.0     ...       550.0      sqft     NaN
# 15064257       False       2.0     ...      1299.0      sqft     NaN
# 15064295       False       2.0     ...      1033.0      sqft     NaN
# ...

# %%
# Convert Boolean to binary variable
df.IsAStudio = 1*df['IsAStudio']

# %%
df
# Out:
#                                                Address DateOfSale  SalePrice  \
# ID
# 15063471     55 Vandewater St APT 9, San Francisco, CA    12/4/15   710000.0
# 15064257    111 Chestnut St APT 403, San Francisco, CA    1/15/16   970000.0
# 15064295    111 Chestnut St APT 702, San Francisco, CA   12/17/15   940000.0
# ...                                                ...        ...        ...
# 2108546010    1738 Lombard St APT 4, San Francisco, CA    1/14/16  1400000.0
# 2121221385            925 Larkin St, San Francisco, CA   11/30/15  1430000.0
# 2122992200           129 Octavia St, San Francisco, CA   11/20/15  2750000.0
#
#            IsAStudio  BedCount     ...        Size  SizeUnit LotSize  \
# ID                                 ...
# 15063471           0       1.0     ...       550.0      sqft     NaN
# 15064257           0       2.0     ...      1299.0      sqft     NaN
# 15064295           0       2.0     ...      1033.0      sqft     NaN
# ...

# %%
#Size:
df.SizeUnit.unique()
#not a useful varible, sqft or Nan, can simply just drop this. 
df.drop('SizeUnit', axis = 1, inplace = True)

# %%
#Scale LotSize
df.LotSizeUnit.unique()
#convert acre to sqft.
# Out:
# array([nan, 'sqft', 'ac'], dtype=object)

# %%
#Group1: the NA values 
df_na = df[df.LotSizeUnit.isnull()]
df_na
# Out:
#                                                Address DateOfSale  SalePrice  \
# ID
# 15063471     55 Vandewater St APT 9, San Francisco, CA    12/4/15   710000.0
# 15064257    111 Chestnut St APT 403, San Francisco, CA    1/15/16   970000.0
# 15064295    111 Chestnut St APT 702, San Francisco, CA   12/17/15   940000.0
# ...                                                ...        ...        ...
# 2108546010    1738 Lombard St APT 4, San Francisco, CA    1/14/16  1400000.0
# 2121221385            925 Larkin St, San Francisco, CA   11/30/15  1430000.0
# 2122992200           129 Octavia St, San Francisco, CA   11/20/15  2750000.0
#
#            IsAStudio  BedCount  BathCount    Size  LotSize LotSizeUnit  \
# ID
# 15063471           0       1.0        NaN   550.0      NaN         NaN
# 15064257           0       2.0        2.0  1299.0      NaN         NaN
# 15064295           0       2.0        2.0  1033.0      NaN         NaN
# ...

# %%
#Group 2: The Sqft values 
df_sqft = df[df.LotSizeUnit == 'sqft']
df_sqft = df_sqft.drop('LotSizeUnit', axis =1)
df_sqft.shape
# Out:
# (552, 9)

# %%
#Group 3: The Ac values
df_ac = df[df.LotSizeUnit == 'ac']
df_ac = df_ac.drop('LotSizeUnit', axis = 1)
df_ac.shape
# Out:
# (4, 9)

# %%
#Scale ac to square
# 1 acre = 43,560 sqft
df_ac.LotSize = df_ac.LotSize * 43560

# %%
df = pd.concat([df_na,df_sqft,df_ac]).sort_index()
df = df.drop(['LotSizeUnit'], axis =1)
df
# Out:
#                                               Address  BathCount  BedCount  \
# ID
# 15063471    55 Vandewater St APT 9, San Francisco, CA        NaN       1.0
# 15063505          740 Francisco St, San Francisco, CA        2.0       NaN
# 15063609          819 Francisco St, San Francisco, CA        3.5       2.0
# ...                                               ...        ...       ...
# 2128308939       33 Santa Cruz Ave, San Francisco, CA        3.0       3.0
# 2131957929          1821 Grant Ave, San Francisco, CA        2.0       2.0
# 2136213970           1200 Gough St, San Francisco, CA        1.0       1.0
#
#             BuiltInYear DateOfSale IsAStudio  LotSize  SalePrice    Size
# ID
# 15063471         1980.0    12/4/15         0      NaN   710000.0   550.0
# 15063505         1948.0   11/30/15         0   2435.0  2150000.0  1430.0
# 15063609         1976.0   11/12/15         0   3920.0  5600000.0  2040.0
# ...
